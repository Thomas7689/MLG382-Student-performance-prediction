# %%
BrightPath Academy - Guided ML Project
Steps 1 to 4: Problem Statement to Data Understanding

# Step 1: Problem Statement
BrightPath Academy aims to improve academic performance and student support by leveraging student data. 
The institution needs a machine learning solution that can:
- Detect at-risk students early
- Personalize intervention strategies (e.g., tutoring, mentoring)
- Analyze the impact of extracurricular activities on performance
- Convert raw data into actionable insights

# Step 2: Hypothesis Generation
Hypotheses:
1. Higher parental support is associated with better academic performance.
2. Participation in extracurricular activities leads to higher GPA.
3. Increased study time and fewer absences result in higher performance.
4. Tutoring improves student outcomes.
5. Demographic factors (e.g., gender, parental education) may influence GPA.
# Out:
# '\nHypotheses:\n1. Higher parental support is associated with better academic performance.\n2. Participation in extracurricular activities leads to higher GPA.\n3. Increased study time and fewer absences result in higher performance.\n4. Tutoring improves student outcomes.\n5. Demographic factors (e.g., gender, parental education) may influence GPA.\n'

# %%
# Step 3: Getting the system ready and loading the data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning-related
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Load the dataset
file_path = "Student_performance_data.csv"
df = pd.read_csv('../Student_performance_data.csv')

# %%
# Step 4: Understanding the data
print("\n--- Dataset Info ---")
df.info()

print("\n--- First 5 Rows ---")
print(df.head())

print("\n--- Descriptive Statistics ---")
print(df.describe(include='all'))

print("\n--- Checking for Missing Values ---")
print(df.isnull().sum())
# Out:
# --- Dataset Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# ...
