# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading CSV

# %%
df = pd.read_csv('../Student_performance_data.csv')

# %% [markdown]
# ### Running Random Forest

# %%
# %run "../Model building/RandomForrest.ipynb"
# Out:
# 4.0

# %% [markdown]
# ### Evaluation model

# %%
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    
    print("Accuracy:", accuracy_score(y_test, y_pred), "%")
    print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=['A', 'B', 'C', 'D', 'F'], zero_division=0))

    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['A','B','C','D','F'], yticklabels=['A','B','C','D','F'])
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()

# %%
evaluate_model(rf, xTest, yTest)
# Out:
# Accuracy: 0.906054279749478 %
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            A       0.00      0.00      0.00        23
#            B       0.72      0.88      0.79        49
#            C       0.90      0.91      0.91        82
#            D       0.90      0.92      0.91        76
#            F       0.95      0.99      0.97       249
#
#     accuracy                           0.91       479
#    macro avg       0.69      0.74      0.72       479
# weighted avg       0.87      0.91      0.89       479
