# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %run "../Model building/Logistic regression.ipynb"

# %%
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    
    print("Accuracy:", accuracy_score(y_test, y_pred), "%")
    print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=['A', 'B', 'C', 'D', 'F'], zero_division=0))

    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['A','B','C','D','F'], yticklabels=['A','B','C','D','F'])
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()

# %%
evaluate_model(lr, xTest, yTest)
# Out:
# Accuracy: 0.7473903966597077 %
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            A       0.25      0.05      0.09        19
#            B       0.72      0.54      0.62        57
#            C       0.55      0.76      0.64        70
#            D       0.61      0.45      0.51        83
#            F       0.86      0.94      0.90       250
#
#     accuracy                           0.75       479
#    macro avg       0.60      0.55      0.55       479
# weighted avg       0.73      0.75      0.73       479
