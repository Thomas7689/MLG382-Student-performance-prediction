# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
# %run "../Model building/Linear regression.ipynb"

# %%
y_true = yTest['Absences']
y_pred = yTestPrediction['Absences']

# %%
mae = mean_absolute_error(y_true, y_pred)
mse = mean_squared_error(y_true, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_true, y_pred)

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R-squared (R²):", r2)
# Out:
# Mean Absolute Error (MAE): 4.481161516641023
# Mean Squared Error (MSE): 33.575075742114265
# Root Mean Squared Error (RMSE): 5.794400378133553
# R-squared (R²): 0.4681523087898076
