# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
# %run "../Model building/Linear regression.ipynb"

# %%
y_true = yTest['Absences']
y_pred = yTestPrediction['Absences']

# %%
mae = mean_absolute_error(y_true, y_pred)
mse = mean_squared_error(y_true, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_true, y_pred)

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R-squared (R²):", r2)
# Out:
# Mean Absolute Error (MAE): 4.618200236206437
# Mean Squared Error (MSE): 34.14918349172969
# Root Mean Squared Error (RMSE): 5.843730271986352
# R-squared (R²): 0.5328244926370254
