# %% [markdown]
# ### Import Libraries

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %run "../Model building/Deep learning.ipynb"

# %%
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    
    print("Accuracy:", accuracy_score(y_test, y_pred), "%")
    print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=['A', 'B', 'C', 'D', 'F'], zero_division=0))

    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['A','B','C','D','F'], yticklabels=['A','B','C','D','F'])
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()

# %%
evaluate_model(clf, xTest, yTest)
# Out:
# Accuracy: 0.872651356993737 %
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            A       1.00      0.11      0.20        18
#            B       0.84      0.82      0.83        57
#            C       0.84      0.88      0.86        80
#            D       0.83      0.75      0.79        87
#            F       0.90      0.99      0.94       237
#
#     accuracy                           0.87       479
#    macro avg       0.88      0.71      0.72       479
# weighted avg       0.87      0.87      0.86       479
