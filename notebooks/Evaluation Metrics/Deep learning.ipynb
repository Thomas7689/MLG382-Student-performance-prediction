# %% [markdown]
# ### Import Libraries

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %run "../Model building/Deep learning.ipynb"

# %%
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    
    print("Accuracy:", accuracy_score(y_test, y_pred), "%")
    print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=['A', 'B', 'C', 'D', 'F'], zero_division=0))

    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['A','B','C','D','F'], yticklabels=['A','B','C','D','F'])
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()

# %%
evaluate_model(clf, xTest, yTest)
# Out:
# Accuracy: 0.8079331941544885 %
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            A       0.88      0.32      0.47        22
#            B       0.80      0.66      0.72        53
#            C       0.70      0.83      0.76        63
#            D       0.64      0.61      0.63        83
#            F       0.89      0.94      0.91       258
#
#     accuracy                           0.81       479
#    macro avg       0.78      0.67      0.70       479
# weighted avg       0.81      0.81      0.80       479
